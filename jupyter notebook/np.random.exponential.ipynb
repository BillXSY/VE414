# %%
import numpy as np
import matplotlib.pylab as plt

# %%
data = np.random.exponential(scale=2,size=10000)
data.sort()
cnt = plt.hist(data, bins=50)

# %%
data = np.random.exponential(scale=3,size=10000)
data.sort()
cnt = plt.hist(data, bins=50)
